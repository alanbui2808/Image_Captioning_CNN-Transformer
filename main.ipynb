# %%
import numpy as np

# %%
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
a = np.array([2,2,3,3])

# %%
b = np.array([1,2,3,4])

# %%
print(a+b)
# Out:
# [3 4 6 7]

# %%
print('hello Alan')
# Out:
# hello Alan
